# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plt.rc('xtick', labelsize=6)
plt.rc('ytick', labelsize=7)

# %%
def LookupTable(value,type='class'):
    try:
        classes = {
            'A00':[0,0],'A10':[0,1],'A11':[0,1],'A12':[0,1],'A13':[0,1],'A20':[0,2],
            'A21':[0,3],'A22':[0,1],'A30':[0,1],'B00':[3,0],'B10':[3,1],'B11':[3,1],
            'B12':[3,1],'B13':[3,1],'B14':[3,1],'B15':[3,1],'B16':[3,1],'B17':[3,1],
            'B18':[3,1],'B19':[3,1],'B20':[3,1],'B21':[3,1],'B22':[3,1],'B23':[3,1],
            'B30':[3,1],'B31':[3,1],'B32':[3,1],'B33':[3,1],'B34':[3,1],'B35':[3,1],
            'B36':[3,1],'B37':[3,1],'B40':[3,1],'B41':[3,1],'B42':[3,1],'B43':[3,1],
            'B44':[3,1],'B45':[3,1],'B50':[2,1],'B51':[2,1],'B52':[2,1],'B53':[2,1],
            'B54':[3,1],'B55':[2,1],'B70':[3,1],'B71':[3,1],'B72':[3,1],'B73':[3,1],
            'B74':[3,1],'B75':[3,1],'B76':[3,1],'B77':[3,1],'B80':[3,2],'B81':[3,1],
            'B82':[3,1],'B83':[0,1],'B84':[3,3],'C00':[0,0],'C10':[0,1],'C20':[0,1],
            'C21':[0,1],'C22':[0,1],'C23':[0,1],'C30':[0,1],'C31':[0,1],'C32':[0,1],
            'C33':[0,1],'D00':[1,0],'D10':[1,2],'D20':[1,2],'E00':[1,0],'E10':[1,2],
            'E20':[1,2],'E30':[0,1],'F00':[0,0],'F10':[0,1],'F20':[0,1],'F30':[0,3],
            'F40':[0,1],'G10':[0,1],'G11':[0,1],'G12':[0,1],'G20':[0,1],'G21':[0,1],
            'G22':[0,1],'G30':[0,1],'G50':[0,1],'H00':[1,0],'H10':[1,1],'H11':[1,1],
            'H12':[1,1],'H20':[0,2],'H21':[1,1],'H22':[0,1],'H23':[0,1]
        }
        mainClass = {
            '0':'Other',
            '1':'Natural and Semi-natural grass',
            '2':'Seeded grass',
            '3':'Crops and other related agricultural practices',
       }
        if type == 'class':
            result = mainClass[str(classes[value][0])]
        elif type == 'weight':
            result = classes[value][1]
    except:
        if type == 'class':
            result = 'Not classified'
        elif type == 'weight':
            result = -1
        
    return result

# %% [markdown]
# ### Get data from LUCAS LULC data
# #### Landuse: meaning the socioeconomic use of land (for instance, agriculture, forestry, recreation or residential use).
# #### Landcover: for instance crops, grass, broad-leaved forest, or built-up are

# %%
originalData = '../datasets/03_LUCAS/lucas_harmo_uf.csv'
df = pd.read_csv(originalData,sep=',',low_memory=False)
df
# Out:
#               id  point_id  year nuts0 nuts1 nuts2  nuts3     th_lat  \
# 0        1252839  26381958  2015    PT   PT1  PT17    NaN  38.757771
# 1          24355  26421958  2015    PT   PT1  PT17    NaN  38.766957
# 2          42407  26441958  2015    PT   PT1  PT17    NaN  38.771543
# 3        1257765  26461768  2015    PT   PT1  PT15    NaN  37.112502
# 4        1249169  26461958  2015    PT   PT1  PT17    NaN  38.776123
# ...          ...       ...   ...   ...   ...   ...    ...        ...
# 1351288   207428  45883932  2018    SE   SE2  SE23  SE232  58.412369
# 1351289   224760  31822336  2018    ES   ES1  ES13  ES130  43.168171
# 1351290   242545  34041762  2018    ES   ES5  ES52  ES521  38.374810
# 1351291   192650  49323404  2018    PL   PL6  PL61  PL616  53.394034
# 1351292   141622  51743566  2018    LT   LT0  LT02  LT024  54.493570
#
#            th_long  office_pi  ...       photo_east       photo_west  \
# 0        -9.476111        NaN  ...      Photo taken      Photo taken
# 1        -9.431407        1.0  ...     Not relevant     Not relevant
# 2        -9.409051        1.0  ...     Not relevant     Not relevant
# 3        -8.906504        NaN  ...      Photo taken      Photo taken
# 4        -9.386692        NaN  ...      Photo taken      Photo taken
# ...            ...        ...  ...              ...              ...
# 1351288  14.563829        1.0  ...  Photo not taken  Photo not taken
# 1351289  -4.060611        1.0  ...  Photo not taken  Photo not taken
# 1351290  -0.459298        1.0  ...  Photo not taken  Photo not taken
# 1351291  19.212378        1.0  ...  Photo not taken  Photo not taken
# 1351292  23.246482        1.0  ...  Photo not taken  Photo not taken
#
#                                       transect revisit  th_gps_dist  \
# 0                       D20;61;51;61;C22;21;61       3   104.912224
# 1                             PI;D20;61;D20;PI       1          NaN
# 2        PI;C10;61;C10;61;C10;61;C10;61;C10;PI       2          NaN
# 3                                   D10;61;D20       4     0.384871
# 4               PI;C10;PI;C10;61;C10;PI;C10;PI       1    95.260485
# ...                                        ...     ...          ...
# 1351288                                    NaN       2          NaN
# 1351289                                    NaN       1          NaN
# 1351290                                    NaN       1          NaN
# 1351291                                    NaN       1          NaN
# 1351292                                    NaN       4          NaN
#
#                                      file_path_gisco_north  \
# 0        https://gisco-services.ec.europa.eu/lucas/phot...
# 1                                                      NaN
# 2                                                      NaN
# 3        https://gisco-services.ec.europa.eu/lucas/phot...
# 4        https://gisco-services.ec.europa.eu/lucas/phot...
# ...                                                    ...
# 1351288                                                NaN
# 1351289                                                NaN
# 1351290                                                NaN
# 1351291                                                NaN
# 1351292                                                NaN
#
#                                      file_path_gisco_south  \
# 0        https://gisco-services.ec.europa.eu/lucas/phot...
# 1                                                      NaN
# 2                                                      NaN
# 3        https://gisco-services.ec.europa.eu/lucas/phot...
# 4        https://gisco-services.ec.europa.eu/lucas/phot...
# ...                                                    ...
# 1351288                                                NaN
# 1351289                                                NaN
# 1351290                                                NaN
# 1351291                                                NaN
# 1351292                                                NaN
#
#                                       file_path_gisco_east  \
# 0        https://gisco-services.ec.europa.eu/lucas/phot...
# 1                                                      NaN
# 2                                                      NaN
# 3        https://gisco-services.ec.europa.eu/lucas/phot...
# 4        https://gisco-services.ec.europa.eu/lucas/phot...
# ...                                                    ...
# 1351288                                                NaN
# 1351289                                                NaN
# 1351290                                                NaN
# 1351291                                                NaN
# 1351292                                                NaN
#
#                                       file_path_gisco_west  \
# 0        https://gisco-services.ec.europa.eu/lucas/phot...
# 1                                                      NaN
# 2                                                      NaN
# 3        https://gisco-services.ec.europa.eu/lucas/phot...
# 4        https://gisco-services.ec.europa.eu/lucas/phot...
# ...                                                    ...
# 1351288                                                NaN
# 1351289                                                NaN
# 1351290                                                NaN
# 1351291                                                NaN
# 1351292                                                NaN
#
#                                      file_path_gisco_point
# 0        https://gisco-services.ec.europa.eu/lucas/phot...
# 1                                                      NaN
# 2                                                      NaN
# 3        https://gisco-services.ec.europa.eu/lucas/phot...
# 4        https://gisco-services.ec.europa.eu/lucas/phot...
# ...                                                    ...
# 1351288                                                NaN
# 1351289                                                NaN
# 1351290                                                NaN
# 1351291                                                NaN
# 1351292                                                NaN
#
# [1351293 rows x 117 columns]

# %%
(round((df.isnull().sum()/df.shape[0])*100,2)).head(50)
# Out:
# id                       0.00
# point_id                 0.00
# year                     0.00
# nuts0                    0.12
# nuts1                    0.12
# nuts2                    0.12
# nuts3                   75.00
# th_lat                   0.00
# th_long                  0.00
# office_pi               70.06
# ex_ante                 75.00
# survey_date              0.00
# car_latitude            75.00
# car_ew                  75.00
# car_longitude           75.00
# gps_proj                 0.00
# gps_prec                 0.00
# gps_altitude            12.46
# gps_lat                  0.00
# gps_ew                   0.00
# gps_long                 0.00
# obs_dist                 7.38
# obs_direct               0.00
# obs_type                 0.00
# obs_radius              25.01
# letter_group             0.00
# lc1                      0.00
# lc1_label                0.00
# lc1_spec                12.46
# lc1_spec_label          12.46
# lc1_perc                12.46
# lc2                      0.00
# lc2_label               11.37
# lc2_spec                29.81
# lc2_spec_label          29.81
# lc2_perc                12.46
# lu1                      0.00
# lu1_label                0.00
# lu1_type                49.83
# lu1_type_label          49.83
# lu1_perc                49.83
# lu2                      0.00
# lu2_label                0.00
# lu2_type                49.83
# lu2_type_label          49.83
# lu2_perc                49.83
# parcel_area_ha          12.46
# tree_height_maturity    29.83
# tree_height_survey      12.89
# feature_width           12.92
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
len(df.lc1.unique())
# Out:
# 81

# %%
df['gpw_lulc_class'] = df['lc1'].apply(lambda x: LookupTable(x,'class'))
df['sample_weight'] = df['lc1'].apply(lambda x: LookupTable(x,'weight'))

# %%
df[df.gpw_lulc_class == 'Not classified']['lc1'].unique()
# Out:
# array(['BX1', 'BX2', '8'], dtype=object)

# %%
df.gpw_lulc_class.value_counts()
# Out:
# gpw_lulc_class
# Other                                             600920
# Natural and Semi-natural grass                    365691
# Crops and other related agricultural practices    344936
# Seeded grass                                       25237
# Not classified                                     14509
# Name: count, dtype: int64

# %%
newdf = df[['th_long','th_lat','year','lc1_label','gpw_lulc_class','sample_weight']].copy()
newdf.rename(columns={
    'th_long':'longitude',
    'th_lat':'latitude',
    'year':'reference_year',
    'lc1_label':'original_lulc_class'},inplace=True)
newdf['dataset_name'] = 'Lucas'
newdf['observation'] = ''
newdf
# Out:
#          longitude   latitude  reference_year  \
# 0        -9.476111  38.757771            2015
# 1        -9.431407  38.766957            2015
# 2        -9.409051  38.771543            2015
# 3        -8.906504  37.112502            2015
# 4        -9.386692  38.776123            2015
# ...            ...        ...             ...
# 1351288  14.563829  58.412369            2018
# 1351289  -4.060611  43.168171            2018
# 1351290  -0.459298  38.374810            2018
# 1351291  19.212378  53.394034            2018
# 1351292  23.246482  54.493570            2018
#
#                       original_lulc_class                  gpw_lulc_class  \
# 0            Shrubland without tree cover  Natural and Semi-natural grass
# 1            Shrubland without tree cover  Natural and Semi-natural grass
# 2                    Broadleaved woodland                           Other
# 3        Shrubland with sparse tree cover  Natural and Semi-natural grass
# 4                    Broadleaved woodland                           Other
# ...                                   ...                             ...
# 1351288         Inland fresh water bodies                           Other
# 1351289      Non built-up linear features                           Other
# 1351290      Non built-up linear features                           Other
# 1351291         Inland fresh water bodies                           Other
# 1351292      Non built-up linear features                           Other
#
#          sample_weight dataset_name observation
# 0                    2        Lucas
# 1                    2        Lucas
# 2                    1        Lucas
# 3                    2        Lucas
# 4                    1        Lucas
# ...                ...          ...         ...
# 1351288              1        Lucas
# 1351289              1        Lucas
# 1351290              1        Lucas
# 1351291              1        Lucas
# 1351292              1        Lucas
#
# [1351293 rows x 8 columns]

# %%
newdf.describe()
# Out:
#           longitude      latitude  reference_year  sample_weight
# count  1.351293e+06  1.351293e+06    1.351293e+06   1.351293e+06
# mean   1.326705e+02  2.447568e+02    2.012987e+03   1.251475e+00
# std    1.820695e+04  2.866522e+04    4.042502e+00   5.424070e-01
# min   -1.055242e+01  3.457025e+01    2.006000e+03  -1.000000e+00
# 25%    4.294553e-01  4.303737e+01    2.009000e+03   1.000000e+00
# 50%    1.124675e+01  4.812544e+01    2.015000e+03   1.000000e+00
# 75%    1.886955e+01  5.291932e+01    2.018000e+03   2.000000e+00
# max    3.514000e+06  4.932000e+06    2.018000e+03   3.000000e+00

# %%
newdf['observation'] = np.where(newdf.longitude >=1.5e+06,'Outliers',newdf['observation'])
newdf
# Out:
#          longitude   latitude  reference_year  \
# 0        -9.476111  38.757771            2015
# 1        -9.431407  38.766957            2015
# 2        -9.409051  38.771543            2015
# 3        -8.906504  37.112502            2015
# 4        -9.386692  38.776123            2015
# ...            ...        ...             ...
# 1351288  14.563829  58.412369            2018
# 1351289  -4.060611  43.168171            2018
# 1351290  -0.459298  38.374810            2018
# 1351291  19.212378  53.394034            2018
# 1351292  23.246482  54.493570            2018
#
#                       original_lulc_class                  gpw_lulc_class  \
# 0            Shrubland without tree cover  Natural and Semi-natural grass
# 1            Shrubland without tree cover  Natural and Semi-natural grass
# 2                    Broadleaved woodland                           Other
# 3        Shrubland with sparse tree cover  Natural and Semi-natural grass
# 4                    Broadleaved woodland                           Other
# ...                                   ...                             ...
# 1351288         Inland fresh water bodies                           Other
# 1351289      Non built-up linear features                           Other
# 1351290      Non built-up linear features                           Other
# 1351291         Inland fresh water bodies                           Other
# 1351292      Non built-up linear features                           Other
#
#          sample_weight dataset_name observation
# 0                    2        Lucas
# 1                    2        Lucas
# 2                    1        Lucas
# 3                    2        Lucas
# 4                    1        Lucas
# ...                ...          ...         ...
# 1351288              1        Lucas
# 1351289              1        Lucas
# 1351290              1        Lucas
# 1351291              1        Lucas
# 1351292              1        Lucas
#
# [1351293 rows x 8 columns]

# %%
newdf[newdf['observation'] != 'Outliers']
# Out:
#          longitude   latitude  reference_year  \
# 0        -9.476111  38.757771            2015
# 1        -9.431407  38.766957            2015
# 2        -9.409051  38.771543            2015
# 3        -8.906504  37.112502            2015
# 4        -9.386692  38.776123            2015
# ...            ...        ...             ...
# 1351288  14.563829  58.412369            2018
# 1351289  -4.060611  43.168171            2018
# 1351290  -0.459298  38.374810            2018
# 1351291  19.212378  53.394034            2018
# 1351292  23.246482  54.493570            2018
#
#                       original_lulc_class                  gpw_lulc_class  \
# 0            Shrubland without tree cover  Natural and Semi-natural grass
# 1            Shrubland without tree cover  Natural and Semi-natural grass
# 2                    Broadleaved woodland                           Other
# 3        Shrubland with sparse tree cover  Natural and Semi-natural grass
# 4                    Broadleaved woodland                           Other
# ...                                   ...                             ...
# 1351288         Inland fresh water bodies                           Other
# 1351289      Non built-up linear features                           Other
# 1351290      Non built-up linear features                           Other
# 1351291         Inland fresh water bodies                           Other
# 1351292      Non built-up linear features                           Other
#
#          sample_weight dataset_name observation
# 0                    2        Lucas
# 1                    2        Lucas
# 2                    1        Lucas
# 3                    2        Lucas
# 4                    1        Lucas
# ...                ...          ...         ...
# 1351288              1        Lucas
# 1351289              1        Lucas
# 1351290              1        Lucas
# 1351291              1        Lucas
# 1351292              1        Lucas
#
# [1351229 rows x 8 columns]

# %%
crs = "EPSG:4326"
newdf = gpd.GeoDataFrame(newdf, geometry=gpd.points_from_xy(newdf.longitude, newdf.latitude),crs=crs)
newdf.plot()

# %%
newdf.iloc[:,2:].head(5)

# %%
srcout = 
newdf.iloc[:,2:].to_parquet(srcout)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 newdf.iloc[:,2:].to_parquet(srcout)
#
# NameError: name 'srcout' is not defined
